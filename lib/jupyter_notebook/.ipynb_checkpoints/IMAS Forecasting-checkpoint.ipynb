# %%
from matplotlib import pyplot
import numpy as np
from pandas import DataFrame
import pandas as pd
import psycopg2 as pq
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
import yaml


with open(r'../../config/database.yml') as file:
    database_connection = yaml.load(file, Loader=yaml.FullLoader)

conn = pq.connect("dbname=" + database_connection['development']['database'])
cur = conn.cursor()
cur.execute("""
Select
CU.name,
IT.item_number,
IT.item_description,
'Each' as unit_of_measure,
SA.sales_date - (date_part('day', SA.sales_date) - 1)::integer as sales_date,
sum(SA.sales_quantity * IUOM.base_conversion) as sales_quantity

From
sales SA
  Join customers CU
    On CU.id = SA.customer_id
  Join items IT
    On IT.id = SA.item_id
  Join unit_of_measures UOM
    On UOM.id = SA.unit_of_measure_id
  Join item_unit_of_measures IUOM
    On IUOM.item_id = SA.item_id and IUOM.unit_of_measure_id = SA.unit_of_measure_id
    
Where
IT.item_number = 'CCDK200120'
and SA.sales_date between '10/01/17' and '10/31/19'

Group by
CU.name,
IT.item_number,
IT.item_description,
UOM.code,
SA.sales_date - (date_part('day', SA.sales_date) - 1)::integer;
""")

items = cur.fetchall()

col_names = []
for header in cur.description:
    col_names.append(header[0])

cur.close()
conn.close()

data_frame = DataFrame(items, columns=col_names)
data_frame['sales_date'] = pd.to_datetime(data_frame['sales_date'])
data_frame.set_index('sales_date', inplace=True)
data_frame.head(5)
# Out:
#                                     name item_number item_description  \
# sales_date
# 2017-10-01  Costco Wholesale Corporation  CCDK200120        Bacon 20#
# 2017-11-01  Costco Wholesale Corporation  CCDK200120        Bacon 20#
# 2017-12-01  Costco Wholesale Corporation  CCDK200120        Bacon 20#
# 2018-01-01  Costco Wholesale Corporation  CCDK200120        Bacon 20#
# 2018-02-01  Costco Wholesale Corporation  CCDK200120        Bacon 20#
#
#            unit_of_measure  sales_quantity
# sales_date
# 2017-10-01            Each           12710
# 2017-11-01            Each           11110
# 2017-12-01            Each           10630
# 2018-01-01            Each           10990
# 2018-02-01            Each           10090

# %%
timeseries = data_frame[['sales_quantity']]

pyplot.xlabel('sales_date')
pyplot.ylabel('sales_quantity')
pyplot.plot(timeseries)

# %%
def test_stationary(timeseries):
    movingAverage = timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()

    orig = pyplot.plot(timeseries, color='blue', label='Original')
    mean = pyplot.plot(movingAverage, color='red', label='Rolling Mean')
    std = pyplot.plot(movingSTD, color='black', label='Rolling STD')
    pyplot.legend(loc='best')
    pyplot.title('Rolling Mean & Standard Deviation')
    pyplot.show(block=False)
    
    dftest = adfuller(timeseries['sales_quantity'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationary(timeseries)
# Out:
# Test Statistic                 -4.462914
# p-value                         0.000229
# #Lags Used                      0.000000
# Number of Observations Used    24.000000
# Critical Value (1%)            -3.737709
# Critical Value (5%)            -2.992216
# Critical Value (10%)           -2.635747
# dtype: float64

# %%
data_frame_Shifting = timeseries - timeseries.shift()
pyplot.plot(data_frame_Shifting)

# %%
data_frame_Shifting.dropna(inplace=True)
test_stationary(data_frame_Shifting)
# Out:
# Test Statistic                -9.406920e+00
# p-value                        5.977038e-16
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.300000e+01
# Critical Value (1%)           -3.752928e+00
# Critical Value (5%)           -2.998500e+00
# Critical Value (10%)          -2.638967e+00
# dtype: float64

# %%
decomposition = seasonal_decompose(timeseries, freq=12)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

pyplot.subplot(411)
pyplot.plot(timeseries, label="Original")
pyplot.legend(loc='best')
pyplot.subplot(412)
pyplot.plot(trend, label="Trend")
pyplot.legend(loc='best')
pyplot.subplot(413)
pyplot.plot(seasonal, label="Seasonality")
pyplot.legend(loc='best')
pyplot.subplot(414)
pyplot.plot(residual, label="Residuals")
pyplot.legend(loc='best')
pyplot.tight_layout()

# %%
decomposedLogData = residual
decomposedLogData.dropna(inplace=True)
test_stationary(decomposedLogData)
# Out:
# Test Statistic                 -2.886751
# p-value                         0.046910
# #Lags Used                      0.000000
# Number of Observations Used    12.000000
# Critical Value (1%)            -4.137829
# Critical Value (5%)            -3.154972
# Critical Value (10%)           -2.714477
# dtype: float64

# %%
lag_acf = acf(data_frame_Shifting, nlags=12)
lag_pacf = pacf(data_frame_Shifting, nlags=12, method='ols')

pyplot.subplot(121)
pyplot.plot(lag_acf)
pyplot.axhline(y=0, linestyle="--", color="gray")
pyplot.axhline(y=-1.96/np.sqrt(len(data_frame_Shifting)), linestyle="--", color="gray")
pyplot.axhline(y=1.96/np.sqrt(len(data_frame_Shifting)), linestyle="--", color="gray")
pyplot.title("Autocorralation Function")

pyplot.subplot(122)
pyplot.plot(lag_pacf)
pyplot.axhline(y=0, linestyle="--", color="gray")
pyplot.axhline(y=-1.96/np.sqrt(len(data_frame_Shifting)), linestyle="--", color="gray")
pyplot.axhline(y=1.96/np.sqrt(len(data_frame_Shifting)), linestyle="--", color="gray")
pyplot.title("Partial Autocorralation Function")
pyplot.tight_layout()

# %%
model = ARIMA(timeseries, order=(1,1,0), freq='MS')
results_AR = model.fit(disp=-1)
pyplot.plot(data_frame_Shifting)
pyplot.plot(results_AR.fittedvalues, color='red')
pyplot.title('RSS: %.4f'% sum((results_AR.fittedvalues - data_frame_Shifting['sales_quantity'])**2))
# Out:
# Text(0.5, 1.0, 'RSS: 57668163.8450')

# %%
model = ARIMA(timeseries, order=(0,1,1), freq='MS')
results_MA = model.fit(disp=-1)
pyplot.plot(data_frame_Shifting)
pyplot.plot(results_MA.fittedvalues, color='red')
pyplot.title('RSS: %.4f'% sum((results_MA.fittedvalues - data_frame_Shifting['sales_quantity'])**2))
# Out:
# Text(0.5, 1.0, 'RSS: 53006724.0873')

# %%
model = ARIMA(timeseries, order=(1,1,1), freq='MS')
results_ARIMA = model.fit(disp=-1)
pyplot.plot(data_frame_Shifting)
pyplot.plot(results_ARIMA.fittedvalues, color='red')
pyplot.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues - data_frame_Shifting['sales_quantity'])**2))
# Out:
# Text(0.5, 1.0, 'RSS: 52997382.5531')

# %%
prediction_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
prediction_diff.head()
# Out:
# sales_date
# 2017-11-01   -110.494501
# 2017-12-01    625.979545
# 2018-01-01    625.459944
# 2018-02-01     94.201414
# 2018-03-01    676.980517
# dtype: float64

# %%
prediction_ARIMA = pd.Series(timeseries['sales_quantity'], index = timeseries.index)
prediction_ARIMA = prediction_ARIMA.add(prediction_diff, fill_value=0)

pyplot.plot(timeseries)
pyplot.plot(prediction_ARIMA, color='red')
pyplot.title('RMSE: %.4f'% np.sqrt(sum((prediction_ARIMA - timeseries['sales_quantity'])**2)/len(timeseries)))
# Out:
# Text(0.5, 1.0, 'RMSE: 1254.6398')

# %%
results_ARIMA.plot_predict(1, 49)

# %%
results_ARIMA.forecast(steps=24)[0]
# Out:
# array([7692.05912797, 7573.25598127, 7462.66912142, 7352.17359417,
#        7241.67908217, 7131.18458146, 7020.69008088, 6910.1955803 ,
#        6799.70107972, 6689.20657914, 6578.71207855, 6468.21757797,
#        6357.72307739, 6247.22857681, 6136.73407623, 6026.23957565,
#        5915.74507507, 5805.25057449, 5694.7560739 , 5584.26157332,
#        5473.76707274, 5363.27257216, 5252.77807158, 5142.283571  ])
