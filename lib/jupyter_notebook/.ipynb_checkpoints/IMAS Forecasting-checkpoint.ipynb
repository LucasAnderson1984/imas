# %%
from matplotlib import pyplot
import numpy as np
from pandas import DataFrame
import pandas as pd
import psycopg2 as pq
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
import yaml


with open(r'../../config/database.yml') as file:
    database_connection = yaml.load(file, Loader=yaml.FullLoader)

conn = pq.connect("dbname=" + database_connection['development']['database'])
cur = conn.cursor()
cur.execute("""
Select
CU.name,
IT.item_number,
IT.item_description,
'Each' as unit_of_measure,
SA.sales_date - (date_part('day', SA.sales_date) - 1)::integer as sales_date,
sum(SA.sales_quantity * IUOM.base_conversion) as sales_quantity

From
sales SA
  Join customers CU
    On CU.id = SA.customer_id
  Join items IT
    On IT.id = SA.item_id
  Join unit_of_measures UOM
    On UOM.id = SA.unit_of_measure_id
  Join item_unit_of_measures IUOM
    On IUOM.item_id = SA.item_id and IUOM.unit_of_measure_id = SA.unit_of_measure_id
    
Where
IT.item_number = 'CCDK100150'
and SA.sales_date < '11/01/19'

Group by
CU.name,
IT.item_number,
IT.item_description,
UOM.code,
SA.sales_date - (date_part('day', SA.sales_date) - 1)::integer;
""")

items = cur.fetchall()

col_names = []
for header in cur.description:
    col_names.append(header[0])

cur.close()
conn.close()

data_frame = DataFrame(items, columns=col_names)
data_frame['sales_date'] = pd.to_datetime(data_frame['sales_date'])
data_frame.set_index('sales_date', inplace=True)
data_frame.tail(5)
# Out:
#                                     name item_number     item_description  \
# sales_date
# 2019-06-01  Costco Wholesale Corporation  CCDK100150  Original Canine 50#
# 2019-07-01  Costco Wholesale Corporation  CCDK100150  Original Canine 50#
# 2019-08-01  Costco Wholesale Corporation  CCDK100150  Original Canine 50#
# 2019-09-01  Costco Wholesale Corporation  CCDK100150  Original Canine 50#
# 2019-10-01  Costco Wholesale Corporation  CCDK100150  Original Canine 50#
#
#            unit_of_measure  sales_quantity
# sales_date
# 2019-06-01            Each           75250
# 2019-07-01            Each           49190
# 2019-08-01            Each           66550
# 2019-09-01            Each           62140
# 2019-10-01            Each           63600

# %%
timeseries = data_frame[['sales_quantity']]

pyplot.xlabel('sales_date')
pyplot.ylabel('sales_quantity')
pyplot.plot(timeseries)

# %%
def test_stationary(timeseries):
    movingAverage = timeseries.rolling(window=6).mean()
    movingSTD = timeseries.rolling(window=6).std()

    orig = pyplot.plot(timeseries, color='blue', label='Original')
    mean = pyplot.plot(movingAverage, color='red', label='Rolling Mean')
    std = pyplot.plot(movingSTD, color='black', label='Rolling STD')
    pyplot.legend(loc='best')
    pyplot.title('Rolling Mean & Standard Deviation')
    pyplot.show(block=False)
    
    dftest = adfuller(timeseries['sales_quantity'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationary(timeseries)
# Out:
# Test Statistic                -7.048360e+00
# p-value                        5.609813e-10
# #Lags Used                     9.000000e+00
# Number of Observations Used    1.200000e+01
# Critical Value (1%)           -4.137829e+00
# Critical Value (5%)           -3.154972e+00
# Critical Value (10%)          -2.714477e+00
# dtype: float64

# %%
data_frame_Shifting = timeseries - timeseries.shift()
pyplot.plot(data_frame_Shifting)

# %%
data_frame_Shifting.dropna(inplace=True)
test_stationary(data_frame_Shifting)
# Out:
# Test Statistic                 -2.723539
# p-value                         0.070053
# #Lags Used                      7.000000
# Number of Observations Used    13.000000
# Critical Value (1%)            -4.068854
# Critical Value (5%)            -3.127149
# Critical Value (10%)           -2.701730
# dtype: float64

# %%
decomposition = seasonal_decompose(timeseries)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

pyplot.subplot(411)
pyplot.plot(timeseries, label="Original")
pyplot.legend(loc='best')
pyplot.subplot(412)
pyplot.plot(trend, label="Trend")
pyplot.legend(loc='best')
pyplot.subplot(413)
pyplot.plot(seasonal, label="Seasonality")
pyplot.legend(loc='best')
pyplot.subplot(414)
pyplot.plot(residual, label="Residuals")
pyplot.legend(loc='best')
pyplot.tight_layout()
# Out:
#             sales_quantity
# sales_date
# 2018-01-01             NaN
# 2018-02-01             NaN
# 2018-03-01             NaN
# 2018-04-01             NaN
# 2018-05-01             NaN
# 2018-06-01             NaN
# 2018-07-01    67412.916667
# 2018-08-01    67437.500000
# 2018-09-01    67474.583333
# 2018-10-01    67980.000000
# 2018-11-01    67872.500000
# 2018-12-01    67310.416667
# 2019-01-01    67192.083333
# 2019-02-01    66872.916667
# 2019-03-01    67434.166667
# 2019-04-01    66981.875000
# 2019-05-01             NaN
# 2019-06-01             NaN
# 2019-07-01             NaN
# 2019-08-01             NaN
# 2019-09-01             NaN
# 2019-10-01             NaN
